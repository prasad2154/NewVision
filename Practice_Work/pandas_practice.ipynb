# %% [markdown]
# <a href="https://colab.research.google.com/github/prasad2154/NewVision/blob/main/Practice_Work/pandas_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Assignment 1 on *Dmart*
# Q. Select item_name,qty
# Q. Select last 3 columns using loc and iloc
# Q. Display min,max,average price
# Q. Display 1st and last column
# Q. Select middle 3 columns and first 3 rows.
# Q. Select last 2 rows and all columns
# Q. Display total amount

# %%
import pandas as pd
# create first D-Mart dataframe
data = {'id':[1,2,3,4,5],'item_name':['Rice 5kg Bag',
'Detergent Powder','Cooking Oil 1L', 'Biscuit Pack',
'Toothpaste'],'Price':[300,200,150,30,50],'Qty':[1,5,3,2,5],'Amount':[300,1000,450,60,250]}

# %%
df=pd.DataFrame(data)
df
# Out:
#    id         item_name  Price  Qty  Amount
# 0   1      Rice 5kg Bag    300    1     300
# 1   2  Detergent Powder    200    5    1000
# 2   3    Cooking Oil 1L    150    3     450
# 3   4      Biscuit Pack     30    2      60
# 4   5        Toothpaste     50    5     250

# %%
# Q. Select item_name,qty
df[['item_name','Qty']]
# Out:
#           item_name  Qty
# 0      Rice 5kg Bag    1
# 1  Detergent Powder    5
# 2    Cooking Oil 1L    3
# 3      Biscuit Pack    2
# 4        Toothpaste    5

# %%
# Q. Select last 3 columns using loc and iloc
df.iloc[:,2:]
# Out:
#    Price  Qty  Amount
# 0    300    1     300
# 1    200    5    1000
# 2    150    3     450
# 3     30    2      60
# 4     50    5     250

# %%
df.loc[:,['Price','Qty','Amount']]
# Out:
#    Price  Qty  Amount
# 0    300    1     300
# 1    200    5    1000
# 2    150    3     450
# 3     30    2      60
# 4     50    5     250

# %%
# Q. Display min,max,average price
df['Price'].max()
# Out:
# 300

# %%
df['Price'].min()
# Out:
# 30

# %%
print(df['Price'].mean())
# Out:
# 146.0

# %%
# Display first and last column
df[['id',"Amount"]]  #method 1
# Out:
#    id  Amount
# 0   1     300
# 1   2    1000
# 2   3     450
# 3   4      60
# 4   5     250

# %%
# method 2
df.iloc[:,::4]
# Out:
#    id  Amount
# 0   1     300
# 1   2    1000
# 2   3     450
# 3   4      60
# 4   5     250

# %%
df
# Out:
#    id         item_name  Price  Qty  Amount
# 0   1      Rice 5kg Bag    300    1     300
# 1   2  Detergent Powder    200    5    1000
# 2   3    Cooking Oil 1L    150    3     450
# 3   4      Biscuit Pack     30    2      60
# 4   5        Toothpaste     50    5     250

# %%
# Q. Select middle 3 columns and first 3 rows.

df.iloc[:3,1:4]
# Out:
#           item_name  Price  Qty
# 0      Rice 5kg Bag    300    1
# 1  Detergent Powder    200    5
# 2    Cooking Oil 1L    150    3

# %%
# method 2
df.loc[:3,"item_name":"Qty"]
# Out:
#           item_name  Price  Qty
# 0      Rice 5kg Bag    300    1
# 1  Detergent Powder    200    5
# 2    Cooking Oil 1L    150    3
# 3      Biscuit Pack     30    2

# %%
# Q. select last 2 rows and all columns
df.iloc[3:,:]
# Out:
#    id     item_name  Price  Qty  Amount
# 3   4  Biscuit Pack     30    2      60
# 4   5    Toothpaste     50    5     250

# %%
# Method 2
df.loc[3:,'id':'Amount']
# Out:
#    id     item_name  Price  Qty  Amount
# 3   4  Biscuit Pack     30    2      60
# 4   5    Toothpaste     50    5     250

# %%
# Display Total AmOUNT
df['Amount'].sum()
# Out:
# np.int64(2060)

# %% [markdown]
# Assignment 2
# Create a DataFrame for a Library with at least 5 entries.
#
# Columns: book_id | book_name | author | price | copies_sold
#
# Q1. Select book_name and author.
# Q2. Select the last 2 columns using loc and iloc.
# Q3. Display the minimum, maximum, and average price of books.
# Q4. Display the book_id|author|copies_sold
# Q5. Select the middle 3 columns and the first 3 rows.
# Q6. Select the last random 3 rows and all columns.
# Q7. Display the total number of copies_sold.
# Q8. Create a new column total_sales (calculated as price * copies_sold) and display the DataFrame.

# %%
# Q1. Select book_name and author.
# Q2. Select the last 2 columns using loc and iloc.
# Q3. Display the minimum, maximum, and average price of books.
# Q4. Display the book_id|author|copies_sold
# Q5. Select the middle 3 columns and the first 3 rows.
# Q6. Select the last random 3 rows and all columns.
# Q7. Display the total number of copies_sold.
# # Q8. Create a new column total_sales (calculated as price * copies_sold) and display the DataFrame.

# %%
data={'book_id':[11,12,13,14,15],'book_name':["The God of Small Things",
    "Midnight's Children",
    "The White Tiger",
    "A Suitable Boy",
    "Train to Pakistan"],'author':["Arundhati Roy",
    "Salman Rushdie",
    "Aravind Adiga",
    "Vikram Seth",
    "Khushwant Singh"],'Price':[499, 599, 399, 699, 350],'copies_sold':[1200000, 850000, 750000, 1000000, 600000]}

# %%
df1=pd.DataFrame(data)
df1
# Out:
#    book_id                book_name           author  Price  copies_sold
# 0       11  The God of Small Things    Arundhati Roy    499      1200000
# 1       12      Midnight's Children   Salman Rushdie    599       850000
# 2       13          The White Tiger    Aravind Adiga    399       750000
# 3       14           A Suitable Boy      Vikram Seth    699      1000000
# 4       15        Train to Pakistan  Khushwant Singh    350       600000

# %%
# Q1. Select book_name and author.
df1[['book_name','author']]
# Out:
#                  book_name           author
# 0  The God of Small Things    Arundhati Roy
# 1      Midnight's Children   Salman Rushdie
# 2          The White Tiger    Aravind Adiga
# 3           A Suitable Boy      Vikram Seth
# 4        Train to Pakistan  Khushwant Singh

# %%
# Q2. Select the last 2 columns using loc and iloc.
df1.iloc[:,-2:]
# Out:
#    Price  copies_sold
# 0    499      1200000
# 1    599       850000
# 2    399       750000
# 3    699      1000000
# 4    350       600000

# %%
df1.loc[:,'Price':'copies_sold']
# Out:
#    Price  copies_sold
# 0    499      1200000
# 1    599       850000
# 2    399       750000
# 3    699      1000000
# 4    350       600000

# %%
# Q3. Display the minimum, maximum, and average price of books.
df1['Price'].max()
# Out:
# 699

# %%
# Min
df1['Price'].min()
# Out:
# 350

# %%
# Mean
print(df1['Price'].mean())
# Out:
# 509.2

# %%
# Q4. Display the book_id|author|copies_sold
df1[['book_id','author','copies_sold']]
# Out:
#    book_id           author  copies_sold
# 0       11    Arundhati Roy      1200000
# 1       12   Salman Rushdie       850000
# 2       13    Aravind Adiga       750000
# 3       14      Vikram Seth      1000000
# 4       15  Khushwant Singh       600000

# %%
# Q5. Select the middle 3 columns and the first 3 rows.
df1.iloc[:3,1:4]
# Out:
#                  book_name          author  Price
# 0  The God of Small Things   Arundhati Roy    499
# 1      Midnight's Children  Salman Rushdie    599
# 2          The White Tiger   Aravind Adiga    399

# %%
# Q6. Select the last random 3 rows and all columns
df1.iloc[2:,:]
# Out:
#    book_id          book_name           author  Price  copies_sold
# 2       13    The White Tiger    Aravind Adiga    399       750000
# 3       14     A Suitable Boy      Vikram Seth    699      1000000
# 4       15  Train to Pakistan  Khushwant Singh    350       600000

# %%
# Q7. Display the total number of copies_sold.
print(df1['copies_sold'].sum())
# Out:
# 4400000

# %%
# Q8. Create a new column total_sales (calculated as price * copies_sold) and display the DataFrame.

df1['total_sales']=df1['Price']*df1['copies_sold']
df1
# Out:
#    book_id                book_name           author  Price  copies_sold  \
# 0       11  The God of Small Things    Arundhati Roy    499      1200000
# 1       12      Midnight's Children   Salman Rushdie    599       850000
# 2       13          The White Tiger    Aravind Adiga    399       750000
# 3       14           A Suitable Boy      Vikram Seth    699      1000000
# 4       15        Train to Pakistan  Khushwant Singh    350       600000
#
#    total_sales
# 0    598800000
# 1    509150000
# 2    299250000
# 3    699000000
# 4    210000000

# %%
import pandas as pd
path= "/content/HRMS_Dataset_2000_Employees.csv"
d = pd.read_csv(path)

# %%
d.shape
# Out:
# (2000, 15)

# %%
d.columns
# Out:
# Index(['Emp_ID', 'First_Name', 'Last_Name', 'Gender', 'Age', 'Department',
#        'Designation', 'City', 'Email', 'Phone', 'Hire_Date',
#        'Experience_Years', 'Salary', 'Performance_Rating',
#        'Employment_Status'],
#       dtype='object')

# %%
d[["Emp_ID","First_Name","Last_Name","Salary"]]
# Out:
#        Emp_ID First_Name Last_Name  Salary
# 0     EMP0001      Priya     Patil  113696
# 1     EMP0002      Rohan    Shaikh  116506
# 2     EMP0003       Amit    Chavan   97357
# 3     EMP0004     Ananya  Kulkarni  112841
# 4     EMP0005      Rohan     Patel   33675
# ...       ...        ...       ...     ...
# 1995  EMP1996      Arjun    Jadhav   45994
# 1996  EMP1997      Meera  Deshmukh  114080
# 1997  EMP1998        Sai      More   91479
# 1998  EMP1999      Pooja  Deshmukh   26563
# 1999  EMP2000      Meera      More   79114
#
# [2000 rows x 4 columns]

# %%
d.loc[:6,['First_Name', 'Last_Name', 'Gender', 'Age', 'Department']]
# Out:
#   First_Name Last_Name  Gender  Age  Department
# 0      Priya     Patil    Male   29          IT
# 1      Rohan    Shaikh  Female   21       Sales
# 2       Amit    Chavan    Male   45   Marketing
# 3     Ananya  Kulkarni  Female   43   Marketing
# 4      Rohan     Patel  Female   46  Operations
# 5      Nisha     Yadav  Female   35   Marketing
# 6     Vihaan    Chavan  Female   42   Marketing

# %%
d.iloc[:-3,[5,2,3]]
# Out:
#       Department Last_Name  Gender
# 0             IT     Patil    Male
# 1          Sales    Shaikh  Female
# 2      Marketing    Chavan    Male
# 3      Marketing  Kulkarni  Female
# 4     Operations     Patel  Female
# ...          ...       ...     ...
# 1992          IT     Yadav  Female
# 1993     Support     Verma    Male
# 1994       Sales  Deshmukh  Female
# 1995          IT    Jadhav    Male
# 1996   Marketing  Deshmukh    Male
#
# [1997 rows x 3 columns]

# %%
d.duplicated().sum()
# Out:
# np.int64(0)

# %%
d.head()
# Out:
#     Emp_ID First_Name Last_Name  Gender  Age  Department  \
# 0  EMP0001      Priya     Patil    Male   29          IT
# 1  EMP0002      Rohan    Shaikh  Female   21       Sales
# 2  EMP0003       Amit    Chavan    Male   45   Marketing
# 3  EMP0004     Ananya  Kulkarni  Female   43   Marketing
# 4  EMP0005      Rohan     Patel  Female   46  Operations
#
#             Designation     City                         Email       Phone  \
# 0     Software Engineer  Chennai      priya.patil1@company.com  9196001338
# 1         Sales Manager   Nashik     rohan.shaikh2@company.com  9423511615
# 2   Marketing Executive    Delhi      amit.chavan3@company.com  9593103413
# 3        SEO Specialist     Pune  ananya.kulkarni4@company.com  9928327648
# 4  Operations Executive    Delhi      rohan.patel5@company.com  9537672423
#
#     Hire_Date  Experience_Years  Salary  Performance_Rating Employment_Status
# 0  2019-02-24                 3  113696                   5            Active
# ...

# %%
d['City'].unique()
# Out:
# array(['Chennai', 'Nashik', 'Delhi', 'Pune', 'Kolhapur', 'Mumbai',
#        'Bengaluru', 'Sangli', 'Nagpur', 'Hyderabad'], dtype=object)

# %%
d['City'].nunique()
# Out:
# 10

# %%
d.query("Department=='IT'")
# Out:
#        Emp_ID First_Name Last_Name  Gender  Age Department        Designation  \
# 0     EMP0001      Priya     Patil    Male   29         IT  Software Engineer
# 15    EMP0016      Kavya  Deshmukh  Female   29         IT  Software Engineer
# 16    EMP0017      Priya     Gupta    Male   56         IT   Senior Developer
# 22    EMP0023      Meera      Naik  Female   41         IT        QA Engineer
# 31    EMP0032       Amit     Reddy  Female   31         IT   Senior Developer
# ...       ...        ...       ...     ...  ...        ...                ...
# 1977  EMP1978      Sneha      Khan    Male   42         IT        QA Engineer
# 1981  EMP1982       Isha  Deshmukh  Female   30         IT  Software Engineer
# 1992  EMP1993       Amit     Yadav  Female   34         IT  Software Engineer
# 1995  EMP1996      Arjun    Jadhav    Male   49         IT   Senior Developer
# 1998  EMP1999      Pooja  Deshmukh    Male   39         IT       Data Analyst
#
# ...

# %%
d.query("Age == 29 and City == 'Delhi'")
# Out:
#        Emp_ID First_Name Last_Name Gender  Age Department       Designation  \
# 1236  EMP1237       Neha      Naik   Male   29      Admin  Office Executive
# 1848  EMP1849     Aditya    Sharma   Male   29         HR        HR Manager
#
#        City                          Email       Phone   Hire_Date  \
# 1236  Delhi      neha.naik1237@company.com  9208235309  2021-04-30
# 1848  Delhi  aditya.sharma1849@company.com  9745371473  2019-03-22
#
#       Experience_Years  Salary  Performance_Rating Employment_Status
# 1236                 6   26488                   4          On Leave
# 1848                 4   77619                   2            Active

# %%
d['Designation']== "FULL-SIZE"
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1995    False
# 1996    False
# 1997    False
# 1998    False
# 1999    False
# Name: Designation, Length: 2000, dtype: bool

# %%
list(d.groupby(["Age"]))
# Out:
# [((21,),
#          Emp_ID First_Name Last_Name  Gender  Age  Department  \
#   1     EMP0002      Rohan    Shaikh  Female   21       Sales
#   68    EMP0069      Rohan     Yadav    Male   21   Marketing
#   133   EMP0134     Vihaan     Singh  Female   21       Sales
#   200   EMP0201     Sanjay      More    Male   21     Support
#   261   EMP0262      Rohan      Khan  Female   21       Sales
#   ...       ...        ...       ...     ...  ...         ...
#   1796  EMP1797      Arjun  Deshmukh    Male   21       Admin
#   1851  EMP1852       Amit      More    Male   21          HR
#   1953  EMP1954       Amit     Yadav  Female   21   Marketing
#   1956  EMP1957      Priya     Singh    Male   21  Operations
#   1965  EMP1966      Kavya     Joshi  Female   21  Operations
#
#                  Designation       City                           Email  \
#   1            Sales Manager     Nashik       rohan.shaikh2@company.com
# ...

# %%
d.rename(columns={"Emp_ID":"Employee_ID"})
# Out:
#      Employee_ID First_Name Last_Name  Gender  Age  Department  \
# 0        EMP0001      Priya     Patil    Male   29          IT
# 1        EMP0002      Rohan    Shaikh  Female   21       Sales
# 2        EMP0003       Amit    Chavan    Male   45   Marketing
# 3        EMP0004     Ananya  Kulkarni  Female   43   Marketing
# 4        EMP0005      Rohan     Patel  Female   46  Operations
# ...          ...        ...       ...     ...  ...         ...
# 1995     EMP1996      Arjun    Jadhav    Male   49          IT
# 1996     EMP1997      Meera  Deshmukh    Male   45   Marketing
# 1997     EMP1998        Sai      More    Male   42     Finance
# 1998     EMP1999      Pooja  Deshmukh    Male   39          IT
# 1999     EMP2000      Meera      More    Male   56          HR
#
#                Designation       City                           Email  \
# 0        Software Engineer    Chennai        priya.patil1@company.com
# ...

# %%
d.select_dtypes(include=[float,int])
# Out:
#       Age       Phone  Experience_Years  Salary  Performance_Rating
# 0      29  9196001338                 3  113696                   5
# 1      21  9423511615                 0  116506                   3
# 2      45  9593103413                22   97357                   1
# 3      43  9928327648                20  112841                   2
# 4      46  9537672423                24   33675                   5
# ...   ...         ...               ...     ...                 ...
# 1995   49  9021311679                26   45994                   3
# 1996   45  9167811678                24  114080                   4
# 1997   42  9267302209                18   91479                   5
# 1998   39  9198410507                16   26563                   3
# 1999   56  9037846797                32   79114                   1
#
# [2000 rows x 5 columns]

# %%
d.select_dtypes(include=["number"])
# Out:
#       Age       Phone  Experience_Years  Salary  Performance_Rating
# 0      29  9196001338                 3  113696                   5
# 1      21  9423511615                 0  116506                   3
# 2      45  9593103413                22   97357                   1
# 3      43  9928327648                20  112841                   2
# 4      46  9537672423                24   33675                   5
# ...   ...         ...               ...     ...                 ...
# 1995   49  9021311679                26   45994                   3
# 1996   45  9167811678                24  114080                   4
# 1997   42  9267302209                18   91479                   5
# 1998   39  9198410507                16   26563                   3
# 1999   56  9037846797                32   79114                   1
#
# [2000 rows x 5 columns]
