# %% [markdown]
# <a href="https://colab.research.google.com/github/prasad2154/NewVision/blob/main/lambda_Function_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. What is a Lambda Function?
# Problem Statement: Create a simple lambda function that adds 10 to a given num

add_ten = lambda x: x + 10
print(add_ten(5))
# Out:
# 15

# %%
# 2. Lambda Function with Two Arguments
# Problem Statement: Create a lambda function to multiply two numbers

multiply = lambda a,b:a+b
print(multiply(7,9))
# Out:
# 16

# %%
# 3. Lambda Function for Square of a Number
# Problem Statement: Create a lambda function that returns the square of a given number

square = lambda x:x**2
print(square(75))
# Out:
# 5625

# %%
# 4. Lambda with Conditional Expression
# Problem Statement: Create a lambda function to check whether a number is even or odd.

check_even_odd = lambda x: "even" if x%2==0 else "odd"
print(check_even_odd(19))
print(check_even_odd(90))
# Out:
# odd
# even

# %%
# 5. Lambda with map()
#  Use lambda with map() to square every number in a list

numbers =[1,4,5,7,8,9,20]

squares =list(map(lambda x:x**2,numbers))
print(squares)
# Out:
# [1, 16, 25, 49, 64, 81, 400]

# %%
# 6. Lambda with filter()
# Problem Statement: Use lambda with filter() to get only even numbers from a list

numbers =[11,42,53,74,85,96,20]

even_numbers =list(filter(lambda x:x%2==0,numbers))
print(even_numbers)
# Out:
# [42, 74, 96, 20]

# %%
# 7. Lambda with sorted()
# Problem Statement: Sort a list of tuples based on the second value using lambda.

students =[('Amit', 85), ('Neha ', 92), ('Chaitanya', 78),]

sorted_students =sorted(students,key=lambda x:x[1])

print(sorted_students)
# Out:
# [('Chaitanya', 78), ('Amit', 85), ('Neha ', 92)]

# %%
# 8. Lambda with List of Dictionaries
# Problem Statement: Sort employee records based on salary using lambda.

employees = [
    {'name': 'Amit', 'salary': 60000},
    {'name': 'Neha', 'salary': 75000},
    {'name': 'Chaitanya', 'salary': 55000},
]

sorted_employees =sorted(employees,key=lambda x:x['salary'])

print(sorted_employees)
# Out:
# [{'name': 'Chaitanya', 'salary': 55000}, {'name': 'Amit', 'salary': 60000}, {'name': 'Neha', 'salary': 75000}]

# %%
# 9. Lambda Function Returning Maximum of Two Numbers
# Problem Statement: Create a lambda function that returns the maximum of two numbers.

maximum = lambda a , b:a if a>b else b
print(maximum (45,98))
# Out:
# 98

# %%
# 10. Lambda inside Another Function
# Problem Statement: Create a function that returns a lambda function for multiplying a number by a given value

def multiply_by(value):
    return lambda x:x*value

double = multiply_by(2)
triple = multiply_by(3)

print(double(10))
print(triple(10))
# Out:
# 20
# 30

# %%
# 11. Lambda with reduce()
# Problem Statement: Use lambda with reduce() to find the product of all numbers in a list.

from functools import reduce

numbers =[1,2,3,4,5,6,7,8]

product =reduce(lambda x,y:x*y,numbers)

print(product)
# Out:
# 40320

# %%
# 12. Difference Between Lambda and Normal Function
# Problem Statement: Write the same logic using a normal function and a lambda function

# A normal function is defined using def and can contain multiple lines. A lambda function is written in
# one line and is useful for short operations. Both examples return the same result

def add(a , b):
  return a + b

add_lambda = lambda a , b : a + b

print(add(58,75))
print(add_lambda(58,75))
# Out:
# 133
# 133

# %%
# 1.Add Two Numbers Using Lambda

add = lambda x,y :x+y
print(add(78,52))
# Out:
# 130

# %%
# 2. Find Square and Cube Using Lambda

sqaure = lambda x:x**2
cube = lambda x:x**3

print(sqaure(5))
print(cube(5))
# Out:
# 25
# 125

# %%
#  if m. Check Positive, Negative, or Zero

check = lambda n : "Positive" if n >0 else "Negative" if n < 0 else "zero"

print( check(8))
print(check(0))
print(check(-32))
# Out:
# Positive
# zero
# Negative

# %%
# 4. Filter Words Starting with a Specific Letter
words = [ "Apple","Banana","Avocado","Mango","Apricot"]

result = list (filter(lambda word :word.startswith("A"),words))

print(result)
# Out:
# ['Apple', 'Avocado', 'Apricot']

# %%
# 5. Convert List of Strings to Uppercase

name = ["amit","prasad","ravi"]

result = list(map(lambda name:name.upper(),name))
print(result)
# Out:
# ['AMIT', 'PRASAD', 'RAVI']

# %%
# 6. Sort Students by Marks in Descending Order

students = [
    {'name': 'Amit', 'marks': 85},
    {'name': 'Neha', 'marks': 92},
    {'name': 'Chaitanya', 'marks': 78},
]

sorted_students = sorted(students, key=lambda x: x['marks'], reverse=True)

print(sorted_students)
# Out:
# [{'name': 'Neha', 'marks': 92}, {'name': 'Amit', 'marks': 85}, {'name': 'Chaitanya', 'marks': 78}]

# %%
# 7. Sort Employees by Name Length
employee=['Amit','Neha','Chaitanya']

sorted_employees =sorted(employee,key=lambda x:len(x))

print(sorted_employees)
# Out:
# ['Amit', 'Neha', 'Chaitanya']

# %%
# 8. Find Maximum Salary Employee
employees = [
    {'name': 'Amit', 'salary': 60000},
    {'name': 'Neha', 'salary': 75000},
    {'name': 'Chaitanya', 'salary': 55000},
]

highest_salary_employee = max(employees, key=lambda x: x['salary'])

print(highest_salary_employee)
# Out:
# {'name': 'Neha', 'salary': 75000}

# %%
# 9. Remove Empty Strings from a List

data = ["python", "", "is", "awesome", "", "right?"]
result =list(filter(lambda x:x!="",data))
print(result)
# Out:
# ['python', 'is', 'awesome', 'right?']

# %%
# 11. Use Lambda with reduce() to Find Maximum
from functools import reduce

numbers = [23,55,67,62,86,97,12,31]

maximum = reduce(lambda x,y:x if x>y else y,numbers)

print(maximum)
# Out:
# 97

# %%
# 12. Lambda vs def Function

def double_def(x):
  return x*2
double_lambda = lambda x:x*2

print(double_def(5))
print(double_lambda(5))
# Out:
# 10
# 10
