# %% [markdown]
# <a href="https://colab.research.google.com/github/prasad2154/NewVision/blob/main/GenAI/Copy_of_01_chat_api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **How to access API KEY or secretes**

# %%
# approach number 1 in colab
from google.colab import userdata
userdata.get('GEMINI_API_KEY')[-4:]
# Out:
# '0q6Q'

# %%
# approach number 2 using .env

import os

key = os.environ['GEMINI_API_KEY']
key
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_877/1490969067.py in <cell line: 0>()
#       3 import os
#       4
# ----> 5 key = os.environ['GEMINI_API_KEY']
#       6 key
#
# /usr/lib/python3.13/os.py in __getitem__(self, key)
#
# KeyError: 'GEMINI_API_KEY'

# %%
from dotenv import load_dotenv

load_dotenv(dotenv_path='/.env')

key2 = os.getenv('GEMINI_API_KEY')
key2[-5:]
# Out:
# 'C0q6Q'

# %% [markdown]
# **Assignment: Try to access API key using config.ini file**

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# **----------------------------------------------**

# %%
# %pip install google-genai

# %%
from google import genai
import os
from dotenv import load_dotenv

# Load .env file from parent directory
load_dotenv(dotenv_path='./.env')

API_KEY = os.environ["GEMINI_API_KEY"]

client = genai.Client(api_key=API_KEY)

response = client.models.generate_content(
    model='gemini-3.1-pro-preview',
    contents='Give me a small paragraph on Agentic.',
)
print(response.text)
