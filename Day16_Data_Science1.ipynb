# %% [markdown]
# <a href="https://colab.research.google.com/github/prasad2154/NewVision/blob/main/Day16_Data_Science1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Data Science**

# %%
# DS is help u to build a strong domain knowledge

# libraries---- multiple packages included and build one library

# we have 4 important libraries
# Numpy---array+operations
# Pandas----data analysis + plotting
# Matplotlib----plotting and data visualization
# Seaborn---plotting and data visualization

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = "https://raw.githubusercontent.com/hakimyameen/Datasets/refs/heads/main/CO2%20Emissions_Canada.csv"
path
# Out:
# 'https://raw.githubusercontent.com/hakimyameen/Datasets/refs/heads/main/CO2%20Emissions_Canada.csv'

# %%
# load dataset using pandas

df =pd.read_csv(path)
df.head()
# Out:
#     Make       Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 0  ACURA         ILX       COMPACT             2.0          4          AS5
# 1  ACURA         ILX       COMPACT             2.4          4           M6
# 2  ACURA  ILX HYBRID       COMPACT             1.5          4          AV7
# 3  ACURA     MDX 4WD   SUV - SMALL             3.5          6          AS6
# 4  ACURA     RDX AWD   SUV - SMALL             3.5          6          AS6
#
#   Fuel Type  Fuel Consumption City (L/100 km)  \
# 0         Z                               9.9
# 1         Z                              11.2
# 2         Z                               6.0
# 3         Z                              12.7
# 4         Z                              12.1
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                              6.7                               8.5
# 1                              7.7                               9.6
# ...

# %%
# to check rows and column
df.shape
# Out:
# (7385, 12)

# %%
# show me the columns
df.columns
# Out:
# Index(['Make', 'Model', 'Vehicle Class', 'Engine Size(L)', 'Cylinders',
#        'Transmission', 'Fuel Type', 'Fuel Consumption City (L/100 km)',
#        'Fuel Consumption Hwy (L/100 km)', 'Fuel Consumption Comb (L/100 km)',
#        'Fuel Consumption Comb (mpg)', 'CO2 Emissions(g/km)'],
#       dtype='object')

# %%
# show me the abstract summary of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7385 entries, 0 to 7384
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Make                              7385 non-null   object
#  1   Model                             7385 non-null   object
#  2   Vehicle Class                     7385 non-null   object
#  3   Engine Size(L)                    7385 non-null   float64
#  4   Cylinders                         7385 non-null   int64
#  5   Transmission                      7385 non-null   object
#  6   Fuel Type                         7385 non-null   object
#  7   Fuel Consumption City (L/100 km)  7385 non-null   float64
#  8   Fuel Consumption Hwy (L/100 km)   7385 non-null   float64
#  9   Fuel Consumption Comb (L/100 km)  7385 non-null   float64
#  10  Fuel Consumption Comb (mpg)       7385 non-null   int64
# ...

# %%
# to check data type of df
df.dtypes
# Out:
# Make                                 object
# Model                                object
# Vehicle Class                        object
# Engine Size(L)                      float64
# Cylinders                             int64
# Transmission                         object
# Fuel Type                            object
# Fuel Consumption City (L/100 km)    float64
# Fuel Consumption Hwy (L/100 km)     float64
# Fuel Consumption Comb (L/100 km)    float64
# Fuel Consumption Comb (mpg)           int64
# CO2 Emissions(g/km)                   int64
# dtype: object

# %%
# access one column using dot operator
df.Make
# Out:
# 0       ACURA
# 1       ACURA
# 2       ACURA
# 3       ACURA
# 4       ACURA
#         ...
# 7380    VOLVO
# 7381    VOLVO
# 7382    VOLVO
# 7383    VOLVO
# 7384    VOLVO
# Name: Make, Length: 7385, dtype: object

# %%
df.Cylinders
# Out:
# 0       4
# 1       4
# 2       4
# 3       6
# 4       6
#        ..
# 7380    4
# 7381    4
# 7382    4
# 7383    4
# 7384    4
# Name: Cylinders, Length: 7385, dtype: int64

# %%
df.vehicle class
# Out:
#   File "/tmp/ipykernel_1287/2079068340.py", line 1
#     df.vehicle class
#                ^
# SyntaxError: invalid syntax

# %%
# above error bcz of space
# then use another approch []
df['Vehicle Class']
# Out:
# 0              COMPACT
# 1              COMPACT
# 2              COMPACT
# 3          SUV - SMALL
# 4          SUV - SMALL
#              ...
# 7380       SUV - SMALL
# 7381       SUV - SMALL
# 7382       SUV - SMALL
# 7383    SUV - STANDARD
# 7384    SUV - STANDARD
# Name: Vehicle Class, Length: 7385, dtype: object

# %%
df['Fuel Consumption City (L/100 km)']
# Out:
# 0        9.9
# 1       11.2
# 2        6.0
# 3       12.7
# 4       12.1
#         ...
# 7380    10.7
# 7381    11.2
# 7382    11.7
# 7383    11.2
# 7384    12.2
# Name: Fuel Consumption City (L/100 km), Length: 7385, dtype: float64

# %%
# i need unique vehicle class

df['Vehicle Class'].unique()
# Out:
# array(['COMPACT', 'SUV - SMALL', 'MID-SIZE', 'TWO-SEATER', 'MINICOMPACT',
#        'SUBCOMPACT', 'FULL-SIZE', 'STATION WAGON - SMALL',
#        'SUV - STANDARD', 'VAN - CARGO', 'VAN - PASSENGER',
#        'PICKUP TRUCK - STANDARD', 'MINIVAN', 'SPECIAL PURPOSE VEHICLE',
#        'STATION WAGON - MID-SIZE', 'PICKUP TRUCK - SMALL'], dtype=object)

# %%
# how many unique vehicle class
df['Vehicle Class'].nunique()
# Out:
# 16

# %%
df['Vehicle Class'].value_counts()
# Out:
# Vehicle Class
# SUV - SMALL                 1217
# MID-SIZE                    1133
# COMPACT                     1022
# SUV - STANDARD               735
# FULL-SIZE                    639
# SUBCOMPACT                   606
# PICKUP TRUCK - STANDARD      538
# TWO-SEATER                   460
# MINICOMPACT                  326
# STATION WAGON - SMALL        252
# PICKUP TRUCK - SMALL         159
# MINIVAN                       80
# SPECIAL PURPOSE VEHICLE       77
# VAN - PASSENGER               66
# STATION WAGON - MID-SIZE      53
# VAN - CARGO                   22
# Name: count, dtype: int64

# %%
# plot above record using seaborn
# sns.countplot(df[x='Vehicle Class',data=df])
sns.countplot(x='Vehicle Class',data=df)
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(df['Vehicle Class'])
# Out:
# <Axes: xlabel='count', ylabel='Vehicle Class'>
