# %%
s='PYTHON'

# %%
print(s[1])
# Out:
# Y

# %%
print(s[::2])
# Out:
# PTO

# %%
print(s[-1])
# Out:
# N

# %%
print(s[::-1])
# Out:
# NOHTYP

# %%
print(s[-1:1])

# %%
print(s[-3:2])

# %%
print(s[1:3])
# Out:
# YT

# %%
# n[start:stop:step]

n="Prasad"

print(n[::-1])
# Out:
# dasarP

# %%
print(n[-1:0])

# %%
p= 'I love my india'

# %%
# Assignment:
# p = 'I love my India'

# Access my, India, I love, ove, love my, my India

# %%
print(n[1::-1])
# Out:
# rP

# %% [markdown]
# String methods

# %%
# convert str in lower case
s.lower()
# Out:
# 'python'

# %%
s.upper()
# Out:
# 'PYTHON'

# %%
s.capitalize()
# Out:
# 'Python'

# %%
'prasad ramAppa savale'.title()
# Out:
# 'Prasad Ramappa Savale'

# %%
# to remove prefix and suffix use strip() method

# %%
"###python".strip('#')
# Out:
#   File "/tmp/ipykernel_2052/3170820896.py", line 1
#     "###python".strip(#)
#                         ^
# SyntaxError: incomplete input

# %%
# remove spaces presenr in between
'J  A 9999  V  777  A  '

# %%
# ASSIGNMENT   check casefold()
# what is differnce btw casefold()  and lower()

# %%
# when we want to convert lower to upper and vice versa use swapcase() method

h='goOD MornIng'
h.swapcase()
# Out:
# 'GOod mORNiNG'

# %%
# startswith and endswith to return return boolean ans like true false

code='abcdidhioo'
code.startswith('abc')
# Out:
# True

# %%
# join() is used to  prepare a string using a collection

adhar=['1234','4567', '9876']

'-'.join(adhar)
# Out:
# '1234-4567-9876'
