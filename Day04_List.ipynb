# %% [markdown]
# <a href="https://colab.research.google.com/github/prasad2154/NewVision/blob/main/Day04_List.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 `# features of list  []
# it accepts all types of data
# we can crete homo and hetro list
# it preserves sequence of code
# it allows duplicate records
#
# Out:
#   File "/tmp/ipykernel_1371/997833368.py", line 1
#     `# features of list  []
#     ^
# SyntaxError: invalid syntax

# %%
help(list.append)

# %%
# how to create empty list?
a=[]
a

b=list()
b
# Out:
# []

# %%
# assignment-- how to create an empty string?

# %%
# to add element in empty list the we use use append()

a.append(100)

# %%
a
# Out:
# [100]

# %%
# assignment  : try to add str,list,touple,set,dict

# %% [markdown]
# ### Adding different data types to a list using `append()`

# %%
# Add a string to list 'a'
a.append('hello')
display(a)
# Out:
# [100, 'hello']

# %%
# Add another list to list 'a'
a.append([1, 2, 3])
display(a)
# Out:
# [100, 'hello', [1, 2, 3]]

# %%
# Add a tuple to list 'a'
a.append(('x', 'y'))
display(a)
# Out:
# [100, 'hello', [1, 2, 3], ('x', 'y')]

# %%
# Add a set to list 'a'
a.append({'apple', 'banana'})
display(a)
# Out:
# [100, 'hello', [1, 2, 3], ('x', 'y'), {'apple', 'banana'}]

# %%
# Add a dictionary to list 'a'
a.append({'key1': 'value1', 'key2': 123})
display(a)
# Out:
# [100,
#  'hello',
#  [1, 2, 3],
#  ('x', 'y'),
#  {'apple', 'banana'},
#  {'key1': 'value1', 'key2': 123}]

# %%
data=(2,3,4)
data
# add above data in a
# Out:
# (2, 3, 4)

# %%
# a.append(data)   append adss complete objects as it is
a
# Out:
# [100,
#  'hello',
#  [1, 2, 3],
#  ('x', 'y'),
#  {'apple', 'banana'},
#  {'key1': 'value1', 'key2': 123}]

# %%
# use extend() to add indivisual element from iteratable col,ection of elements

# %%
b.extend(data)
b
# Out:
# [2, 3, 4]

# %%
b.extend('c++')
b
# Out:
# [2, 3, 4, 'c', '+', '+']

# %%
# append vs extend

# %%
# to remove elements from list we have 2 methods
# pop(default remove last elements)---index based

b.pop()
b
# Out:
# [2, 3, 4, 'c', '+']

# %%
k=[1,2,3,4,5,6,7]
k
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
k.pop(2)
# Out:
# 3

# %%
k
# Out:
# [1, 2, 4, 5, 6, 7]

# %%
help(k.pop)
# Out:
# Help on built-in function pop:
#
# pop(index=-1, /) method of builtins.list instance
#     Remove and return item at index (default last).
#
#     Raises IndexError if list is empty or index is out of range.

# %%
# remove method ---value based

k
# Out:
# [1, 2, 4, 5, 6, 7]

# %%
k.remove(6)

# %%
k
# Out:
# [1, 2, 4, 5, 7]

# %%
# for duplicate values  ---it remove first occurance value from left to right
t=[1,2,3,4,1,2,3]
t.remove(1)
t
# Out:
# [2, 3, 4, 1, 2, 3]

# %%
# remove all elemnts use clear() method

k.clear()
k
# Out:
# []

# %%
t
# Out:
# [2, 3, 4, 1, 2, 3]

# %%
# shallow copy---- list is with same element but id differnt

x=t.copy()

# %%
x
# Out:
# [2, 3, 4, 1, 2, 3]

# %%
# add -1 in x
x.append(-1)
x
# Out:
# [2, 3, 4, 1, 2, 3, -1]

# %%
t
# Out:
# [2, 3, 4, 1, 2, 3]

# %%
id(t),id(x)
# Out:
# (134035217384640, 134035227749376)

# %%
y=x
y
# Out:
# [2, 3, 4, 1, 2, 3, -1]

# %%
# in bove case we have 1 object with differnt name x,y hence
# if we change in either x/y changes will reflect in both list

x.append('python')

# %%
(x,y)
# Out:
# ([2, 3, 4, 1, 2, 3, -1, 'python'], [2, 3, 4, 1, 2, 3, -1, 'python'])

# %%
# assigmentWe added one list using extend but can we add a tuple to a list using extend?/

# %%
my_list = [1, 2, 3]
my_tuple = (4, 5, 6)

print(f"Original list: {my_list}")
print(f"Tuple to extend: {my_tuple}")

my_list.extend(my_tuple)

print(f"List after extending with tuple: {my_list}")
# Out:
# Original list: [1, 2, 3]
# Tuple to extend: (4, 5, 6)
# List after extending with tuple: [1, 2, 3, 4, 5, 6]
