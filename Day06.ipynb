# %% [markdown]
# <a href="https://colab.research.google.com/github/prasad2154/NewVision/blob/main/Day06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Sets & Dictionary**

# %%
# Both are mutable data types
# set-{at least one element inside}

# %%
s={}
type(s)
# Out:
# dict

# %%
s1={23,}
type(s1)
# Out:
# set

# %%
# features of set
# duplicates are not allowed

p={10,20,30,10,20,30,30,10,10,40,50,50,40,40,20,50,40}
p
# Out:
# {10, 20, 30, 40, 50}

# %%
# set does not preserve  sequence order
q={1,1,2,2,3,3,4,5,5,5,5,6,6,7,'prasad',8,'ml','A'}
q
# Background data strcture of set is a hash table
# Hash table doesnt support indexing and slicing
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 'A', 'ml', 'prasad'}

# %%
# try to delete members from set.
q.pop()
q
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 'A', 'prasad'}

# %%
lot={100,34,5332,54,333,3221,5533,5511,9765,456,8594}
lot
# Out:
# {34, 54, 100, 333, 456, 3221, 5332, 5511, 5533, 8594, 9765}

# %%
winner=lot.pop()
winner
# Out:
# 34

# %%
lot
# Out:
# {54, 100, 333, 456, 3221, 5332, 5511, 5533, 8594, 9765}

# %%
print('Original lot:',lot)
out=lot.pop()
print("element removed:",out,"Currentset",lot)
# Out:
# Original lot: {100, 9765, 5511, 456, 333, 8594, 5332, 3221, 54, 5533}
# element removed: 100 Currentset {9765, 5511, 456, 333, 8594, 5332, 3221, 54, 5533}

# %%
# remove()
lot
# Out:
# {54, 333, 456, 3221, 5332, 5511, 5533, 8594, 9765}

# %%
lot.remove(456)
lot
# Out:
# {54, 3221, 5332, 5511, 5533, 8594, 9765}

# %%
# if we try to delete element which is not present it shows error.

# %%
# assignment : check all the methods

# %%
fruits = {"apple", "banana", "mango", "orange", "grapes"}
fruits
# Out:
# {'apple', 'banana', 'grapes', 'mango', 'orange'}

# %%
fruits.add('kiwi')
fruits
# Out:
# {'apple', 'banana', 'grapes', 'kiwi', 'mango', 'orange'}

# %%
fruits.remove("mango")
fruits
# Out:
# {'apple', 'banana', 'grapes', 'kiwi', 'orange'}

# %%
fruits.copy()
# Out:
# {'apple', 'banana', 'grapes', 'kiwi', 'orange'}

# %%
fruits.pop()
fruits
# Out:
# {'apple', 'banana', 'grapes', 'orange'}
