# %% [markdown]
# # **Basics of Python**

# %% [markdown]
# # Different types of Data type

# %%
# 14 Data types
# Numeric: int,float,complex
# Boolean: True False
# String
# List
# Tuple
# Set
# Dict
# frozenset
# None
# Bytes
# Bytearray
# range
# Out:
# True

# %%
# Python is Dynamically types language
# Static typing- int a = 20 | string s = 'python'
# Dynamic Typing- a = 20| s = 'python'
a = 20
type(a)
# Out:
# int

# %%
s = 'python'
type(s)
# Out:
# str

# %%
a.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_2631/2984306047.py in <cell line: 0>()
# ----> 1 a.upper()
#
# AttributeError: 'int' object has no attribute 'upper'

# %%
x = 'python'
type(x)
# Out:
# str

# %%
x = 10
type(x)
# Out:
# int

# %%
id(x)
# Out:
# 11645640

# %%
id(10)
# Out:
# 11645640

# %%
y = 10
id(y)
# Out:
# 11645640

# %%
id('python')
# Out:
# 135108367432656

# %%
p = 'python'
id(p)
# Out:
# 135108367432656

# %%
q = 'python'
id(q)
# Out:
# 135108367432656

# %%
e = [1,2,3]
id(e)
# Out:
# 135107831648704

# %%
t = [1,2,3]
id(t)
# Out:
# 135107831996544

# %%
# String in Python
# Syntax: ''    ""

# %%
type('.net')
# Out:
# str

# %%
type("c++")
# Out:
# str

# %%
# List
# syntax: []
q = [1,2,3]  # homo.
r = ['A','B','C'] # homo
p = ['X',10,22.22,'Y'] # hetro.

# %%
# Tuple
# syntax: ()
t1 = (1,2,3)
t2 = ('A','B','C') # homo
t3 = ('X',10,22.22,'Y') # hetro.

# %%
type(t1),type(t2),type(t3)
# Out:
# (tuple, tuple, tuple)

# %%
p  # list
# Out:
# ['X', 10, 22.22, 'Y']

# %%
t1 # tuple
# Out:
# (1, 2, 3)

# %%
# list[] vs tuple()
# list is mutable - means we can change the list
p.append(100)
p
# Out:
# ['X', 10, 22.22, 'Y', 100]

# %%
# Assignment: Differences between List and Tuple

t1
# Out:
# (1, 2, 3)

# %%
t2 = (1,2,3)
t2
# Out:
# (1, 2, 3)

# %%
id(t1),id(t2)
# Out:
# (135107833085312, 135107831737728)

# %%
t4 = t2

# %%
id(t2),id(t4)
# Out:
# (135107831737728, 135107831737728)

# %%
# Asisgnment- Shallow copy and Deep copy?
