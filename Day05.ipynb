# %% [markdown]
# <a href="https://colab.research.google.com/github/prasad2154/NewVision/blob/main/Day05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Tuple**

# %%
# syntax  :()

# %%
t=()
type(t)
# empty tuple
# Out:
# tuple

# %%
# tuple has same features as that of list
# it accepts homo and hetro data
# homo   a=(1,2,3,4)   hetro b=(1.23,334,"vinay")

# %%
# tuple support slicing and indexing bcoz background indexing is an array
# tuple preserves sequence order
# duplicates are allowed
# tuple are immutable---we cannot perform the change in original object---tuple,string,range

# %%
 p=[10,20,30]
 p
# Out:
# [10, 20, 30]

# %%
# list is mutable
p[-1]="Prasad"
p
# Out:
# [10, 20, 'Prasad']

# %%
# let us try to understand immutable concept
a=(10,20,30,40)
a
# Out:
# (10, 20, 30, 40)

# %%
a(-1)="panu"
a
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_5685/3553971608.py in <cell line: 0>()
# ----> 1 a[-1]="panu"
#       2 a
#
# TypeError: 'tuple' object does not support item assignment

# %%
# use insert add an element using index
p.insert(0,'laxmi')

# %%
p
# Out:
# ['laxmi', 10, 20, 'Prasad']

# %%
# Tuple has 2 methods---count() and check()

s=(45,55,65,75,85,95)
s
# Out:
# (45, 55, 65, 75, 85, 95)

# %%
s.count(45)
# Out:
# 1

# %%
# tuple packing and unpacking

a=100
b=200
c=300

# packing--combine segregates elements as one entity

nums=(a,b,c)
nums
# Out:
# (100, 200, 300)

# %%
# Unpacking-----it is process of seperating the indivual object as store it in  seperate variable called unpacking.

a,b,c-nums
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_5685/1788315341.py in <cell line: 0>()
#       2 # Unpacking-----it is process of seperating the indivual object as store it in  seperate variable called unpacking.
#       3
# ----> 4 a,b,c-nums
#
# TypeError: unsupported operand type(s) for -: 'int' and 'tuple'
