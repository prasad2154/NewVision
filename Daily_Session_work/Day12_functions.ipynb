# %% [markdown]
# <a href="https://colab.research.google.com/github/prasad2154/NewVision/blob/main/Day12_functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Funtions in Python**
#
#
# 1.  basic building block of python , is a starcture ehich help u to perform an operation
# 2.   Things we need to accomplish in funtion development
#
#
# *   function declaration-function body,operation,loop
# *   function calling--- (function in memory bringing )

# %%
# what is advantage of function??---code reusability

# %%
# addition of 2 numbers

# syntax:
# def function_name():
          # pass


def addition():
  a=int(input("enter first value"))
  b=int(input("enter second value"))
  print("Total:",a+b)

  # only declaration doesnot provide in the output
  # to get the output we need to call the funtion--> function_name()

addition()

# %% [markdown]
# **2 types of funtions**
#
#
# 1.   user defined function
# 2.   Built-in function

# %%
help(len)

# %%
help(print)

# %%
help(addition)

# %% [markdown]
# ##function with arguments**

# %%
def addition(x,y):
  print('Addition:',x+y)
  print('Multiplication:',x*y)
  print('Substraction:',x-y)
  print('division:',x/y)

addition(300,200)

# %% [markdown]
# ##Types of arguments
#
#
# 1.  Positional argument
# 2.  Keyword argument
# 3.  Default argument
# 4.  Variable argument

# %%
#  Positional argument
# these are arg in which sequence order matters

def test(x,y,z):
  print(x,y,z)

test(100,200,400)
test(200,500,700)
# Out:
# 100 200 400
# 200 500 700

# %%
    def info(name,age, sal):
  print('Your name is:',name,'your age is:',age, '& your salary is:',sal  )

info("viki",25,40000)
info("prasad",25,89000)
info(98000,"raj",14)  # when user doesnt follow order then output is nt as per expectations

# %%
# to solve above problem we have keyword argument
# which doesnot required to follow an order
# bcz it directly refers key=value format

info(sal=98000,name="raj",age=14)

# %%
# info("viki",21)---we must supply 3 values for 3 arguments if not the it shows error

# %%
# To avoid missing arguments errors, we can use default arguments.
# Default arguments provide predefined values in the function declaration.
# If the user does not pass a value while calling the function,
# Python automatically uses the default value.

def info(name="Guest", age=25, sal=35000):
    print("Your name is:", name,
          "Your age is:", age,
          "& Your salary is:", sal)

# Function calls
info()                       # Uses all default values
info("Prasad")               # Changes name only
info("Prasad", 22)           # Changes name and age
info("Prasad", 22, 50000)    # Changes all values
# Out:
# Your name is: Guest Your age is: 25 & Your salary is: 35000
# Your name is: Prasad Your age is: 25 & Your salary is: 35000
# Your name is: Prasad Your age is: 22 & Your salary is: 35000
# Your name is: Prasad Your age is: 22 & Your salary is: 50000

# %%
info("sam")
# Out:
# Your name is: sam Your age is: 25 & Your salary is: 35000

# %% [markdown]
# **Rule**
#
# first positional argument and then keyword arg is allowed but first keyword and the positional arg is not allowed.

# %%
def bank_info(b_name,ifsc,place):

# %%
# Variable length args
# 1.variable length positional arg
# 2.variable length keyword arg

def test(n):
  print(n)
test(10)
# Out:
# 10

# %%
# test(10,20,30)

# %%
# 1.variable length positional arg ----to add multiple arguments
# use *
# to solve this issue use
def test(*n):        # * args
  print(n)
test(10,20,30,40)
# Out:
# (10, 20, 30, 40)

# %%
# 2.variable length keyword arg---> **kwargs

def test(**x):
  print(x)

test(num1=45,num2=10,num3=30,num4=88)
# Out:
# {'num1': 45, 'num2': 10, 'num3': 30, 'num4': 88}

# %%
# when we want to cmbine both we can do so
# but first positional and then keyword

def sample(*args ,**kwargs):
  print(args,kwargs)



sample(10,20,30,40,50,num1=45,num2=10,num3=30,num4=88)
# Out:
# (10, 20, 30, 40, 50) {'num1': 45, 'num2': 10, 'num3': 30, 'num4': 88}

# %%
# PRACTICE

def employee_info(name, salary, address):
    print("Employee name is:", name, "Employee salary is:", salary, "& address is:", address)

# positional argument
employee_info("prasad", 65000, "Pune")

# keyword argument
employee_info(name="sanjana",salary=55000,address="mumbai")
# Out:
# Employee name is: prasad Employee salary is: 65000 & address is: Pune
# Employee name is: sanjana Employee salary is: 55000 & address is: mumbai

# %%
# default argument

def employee_info(name="Unknown", salary=44000, address="India"):
    print("Employee name is:", name, "Employee salary is:", salary, "& address is:", address)
employee_info()
employee_info("sanjana")
employee_info("sanjana",55000)
employee_info("sanjana",55000)
# Out:
# Employee name is: Unknown Employee salary is: 44000 & address is: India
# Employee name is: sanjana Employee salary is: 44000 & address is: India
# Employee name is: sanjana Employee salary is: 55000 & address is: India
# Employee name is: sanjana Employee salary is: 55000 & address is: India

# %%
# Vaariable arguments
def marks(*X):
  print(X)
  print(type(X))---#Positional

marks(98,67,54,77,44)
# Out:
# (98, 67, 54, 77, 44)
# <class 'tuple'>

# %%
def account(**x): #-----keyword variable
  print(x)
account(score1=345,score2=500, score3=566, score4=800)
# Out:
# {'score1': 345, 'score2': 500, 'score3': 566, 'score4': 800}

# %%
def account(*x,**y):
  print(x)
  print(y)
account(10,20,30,40,score1=345,score2=500, score3=566, score4=800)
# Out:
# (10, 20, 30, 40)
# {'score1': 345, 'score2': 500, 'score3': 566, 'score4': 800}
