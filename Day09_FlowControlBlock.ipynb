# %% [markdown]
# <a href="https://colab.research.google.com/github/prasad2154/NewVision/blob/main/Day09_FlowControlBlock.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **flow control block**
#
# 1.selective/conditional operators/n
# 2.iterative statements
# 3.Transfer operator

# %%
# 1 selective statement
# these statements
# Conditional operators

# %%
name="prasad"
if name =="prasad":
  print("Good Morning")
# Out:
# Good Morning

# %%
# if condition result is true then ur prpgram control will enter inside the block

# %%
# if we want to check 2 conditions in one if block the use operators(and,or,not)

age=int(input("enter ur age:age"))
country= str(input("enter ur country:"))

if age>18 and country=="India":
    print("You are eligible for vote")
else:
    print("You are not eligible for vote")
# Out:
# enter ur age:age20
# enter ur country:India
# You are eligible for vote

# %%
# if for one check
# if-else for 2 check
# if user want to check more than 2 options then use  elif


amt=int(input("enter ur amount:"))

if amt>100000:
  print("Purchase iphone")
elif amt>90000:
  print("Purchase realme,vivo phones")
elif amt>50000:
  print("Purchase nokia,lava,oppo phones")
else:
  print("Purchase remaining phone")

  # Indentation
  # whenever user takes a block in python it ends with: and at the next line
  # you
# Out:
# enter ur amount:77000
# Purchase nokia,lava,oppo phones

# %%
# 2.Iterative statements
# 1.for loop---> is an iterative loop which fetches one element inside the box
  # syntax for var in collection/iterable

a=[10,20,30,40,50]
for val in a:
    print(val)
# Out:
# 10
# 20
# 30
# 40
# 50

# %%
b="prasad"      #for string
for val in b:
  print(val)
# Out:
# p
# r
# a
# s
# a
# d

# %%
# take dict and apply for loop
d={1:100,2:200,3:300,4:400}
for val in d.items():
  print (val)
# Out:
# (1, 100)
# (2, 200)
# (3, 300)
# (4, 400)

# %%
num1,num2 =(1,100)  #tuple unpacking

# %%
num1
# Out:
# 1

# %%
num2
# Out:
# 100
