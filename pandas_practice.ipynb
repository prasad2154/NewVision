# %% [markdown]
# <a href="https://colab.research.google.com/github/prasad2154/NewVision/blob/main/pandas_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Assignment 1 on *Dmart*
# Q. Select item_name,qty
# Q. Select last 3 columns using loc and iloc
# Q. Display min,max,average price
# Q. Display 1st and last column
# Q. Select middle 3 columns and first 3 rows.
# Q. Select last 2 rows and all columns
# Q. Display total amount

# %%
import pandas as pd
# create first D-Mart dataframe
data = {'id':[1,2,3,4,5],'item_name':['Rice 5kg Bag',
'Detergent Powder','Cooking Oil 1L', 'Biscuit Pack',
'Toothpaste'],'Price':[300,200,150,30,50],'Qty':[1,5,3,2,5],'Amount':[300,1000,450,60,250]}

# %%
df=pd.DataFrame(data)
df
# Out:
#    id         item_name  Price  Qty  Amount
# 0   1      Rice 5kg Bag    300    1     300
# 1   2  Detergent Powder    200    5    1000
# 2   3    Cooking Oil 1L    150    3     450
# 3   4      Biscuit Pack     30    2      60
# 4   5        Toothpaste     50    5     250

# %%
# Q. Select item_name,qty
df[['item_name','Qty']]
# Out:
#           item_name  Qty
# 0      Rice 5kg Bag    1
# 1  Detergent Powder    5
# 2    Cooking Oil 1L    3
# 3      Biscuit Pack    2
# 4        Toothpaste    5

# %%
# Q. Select last 3 columns using loc and iloc
df.iloc[:,2:]
# Out:
#    Price  Qty  Amount
# 0    300    1     300
# 1    200    5    1000
# 2    150    3     450
# 3     30    2      60
# 4     50    5     250

# %%
df.loc[:,['Price','Qty','Amount']]
# Out:
#    Price  Qty  Amount
# 0    300    1     300
# 1    200    5    1000
# 2    150    3     450
# 3     30    2      60
# 4     50    5     250

# %%
# Q. Display min,max,average price
df['Price'].max()
# Out:
# 300

# %%
df['Price'].min()
# Out:
# 30

# %%
print(df['Price'].mean())
# Out:
# 146.0

# %%
# Display first and last column
df[['id',"Amount"]]  #method 1
# Out:
#    id  Amount
# 0   1     300
# 1   2    1000
# 2   3     450
# 3   4      60
# 4   5     250

# %%
# method 2
df.iloc[:,::4]
# Out:
#    id  Amount
# 0   1     300
# 1   2    1000
# 2   3     450
# 3   4      60
# 4   5     250

# %%
df
# Out:
#    id         item_name  Price  Qty  Amount
# 0   1      Rice 5kg Bag    300    1     300
# 1   2  Detergent Powder    200    5    1000
# 2   3    Cooking Oil 1L    150    3     450
# 3   4      Biscuit Pack     30    2      60
# 4   5        Toothpaste     50    5     250

# %%
# Q. Select middle 3 columns and first 3 rows.

df.iloc[:3,1:4]
# Out:
#           item_name  Price  Qty
# 0      Rice 5kg Bag    300    1
# 1  Detergent Powder    200    5
# 2    Cooking Oil 1L    150    3

# %%
# method 2
df.loc[:3,"item_name":"Qty"]
# Out:
#           item_name  Price  Qty
# 0      Rice 5kg Bag    300    1
# 1  Detergent Powder    200    5
# 2    Cooking Oil 1L    150    3
# 3      Biscuit Pack     30    2

# %%
# Q. select last 2 rows and all columns
df.iloc[3:,:]
# Out:
#    id     item_name  Price  Qty  Amount
# 3   4  Biscuit Pack     30    2      60
# 4   5    Toothpaste     50    5     250

# %%
# Method 2
df.loc[3:,'id':'Amount']
# Out:
#    id     item_name  Price  Qty  Amount
# 3   4  Biscuit Pack     30    2      60
# 4   5    Toothpaste     50    5     250

# %%
# Display Total AmOUNT
df['Amount'].sum()
# Out:
# np.int64(2060)
